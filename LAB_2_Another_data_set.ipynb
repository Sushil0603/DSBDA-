# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/Users/sushilpednekar/Documents/Student_performance_10k - Student_performance_10k.csv')

# %%
df.head()
# Out:
#   roll_no gender race_ethnicity parental_level_of_education  lunch  \
# 0  std-01   male        group D                some college    1.0
# 1  std-02   male        group B                 high school    1.0
# 2  std-03   male        group C             master's degree    1.0
# 3  std-04   male        group D                some college    1.0
# 4  std-05   male        group C                some college    0.0
#
#    test_preparation_course math_score  reading_score  writing_score  \
# 0                      1.0         89           38.0           85.0
# 1                      0.0         65          100.0           67.0
# 2                      0.0         10           99.0           97.0
# 3                      1.0         22           51.0           41.0
# 4                      1.0         26           58.0           64.0
#
#    science_score  total_score grade
# 0           26.0        238.0     C
# 1           96.0        328.0     A
# 2           58.0        264.0     B
# ...

# %%
df.dtypes
# Out:
# roll_no                            str
# gender                             str
# race_ethnicity                     str
# parental_level_of_education        str
# lunch                          float64
# test_preparation_course        float64
# math_score                         str
# reading_score                  float64
# writing_score                  float64
# science_score                  float64
# total_score                    float64
# grade                              str
# dtype: object

# %%
df.shape
# Out:
# (10000, 12)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   roll_no                      9999 non-null   str
#  1   gender                       9982 non-null   str
#  2   race_ethnicity               9977 non-null   str
#  3   parental_level_of_education  9978 non-null   str
#  4   lunch                        9976 non-null   float64
#  5   test_preparation_course      9977 non-null   float64
#  6   math_score                   9976 non-null   str
#  7   reading_score                9975 non-null   float64
#  8   writing_score                9976 non-null   float64
#  9   science_score                9977 non-null   float64
#  10  total_score                  9981 non-null   float64
#  11  grade                        9997 non-null   str
# dtypes: float64(6), str(6)
# memory usage: 937.6 KB

# %%
df.isnull().sum()
# Out:
# roll_no                        10000
# gender                            18
# race_ethnicity                    23
# parental_level_of_education       22
# lunch                             24
# test_preparation_course           23
# math_score                        24
# reading_score                     25
# writing_score                     24
# science_score                     23
# total_score                       19
# grade                              3
# dtype: int64

# %%
df['roll_no'] = df['roll_no'].astype(str)

# %%
df.isnull().sum()
# Out:
# roll_no                        10000
# gender                            18
# race_ethnicity                    23
# parental_level_of_education       22
# lunch                             24
# test_preparation_course           23
# math_score                        24
# reading_score                     25
# writing_score                     24
# science_score                     23
# total_score                       19
# grade                              3
# dtype: int64

# %%
df['math_score'] = pd.to_numeric(df['math_score'], errors='coerce')

# %%
df['math_score'] = df['math_score'].fillna(df['math_score'].mean())

# %%
df.isnull().sum()
# Out:
# roll_no                        10000
# gender                            18
# race_ethnicity                    23
# parental_level_of_education       22
# lunch                             24
# test_preparation_course           23
# math_score                         0
# reading_score                     25
# writing_score                     24
# science_score                     23
# total_score                       19
# grade                              3
# dtype: int64

# %%
df['reading_score']=df['reading_score'].fillna(df['reading_score'].mean())

# %%
df['reading_score']
# Out:
# 0        38.0
# 1       100.0
# 2        99.0
# 3        51.0
# 4        58.0
#         ...
# 9995     60.0
# 9996     92.0
# 9997     71.0
# 9998     60.0
# 9999     89.0
# Name: reading_score, Length: 10000, dtype: float64

# %%
df.isnull().sum()
# Out:
# roll_no                        10000
# gender                            18
# race_ethnicity                    23
# parental_level_of_education       22
# lunch                             24
# test_preparation_course           23
# math_score                         0
# reading_score                      0
# writing_score                     24
# science_score                     23
# total_score                       19
# grade                              3
# dtype: int64

# %%
df['gender'] = df['gender'].fillna(df['gender'].mode())

# %%
df['gender'].head(20)
# Out:
# 0     male
# 1     male
# 2     male
# 3     male
# 4     male
# 5     male
# 6      NaN
# 7     male
# 8     male
# 9     male
# 10    male
# 11    male
# 12    male
# 13    male
# 14    male
# 15    male
# 16    male
# 17    male
# 18     Boy
# 19    male
# Name: gender, dtype: str

# %%
df.isnull().sum()
# Out:
# roll_no                        10000
# gender                            18
# race_ethnicity                    23
# parental_level_of_education       22
# lunch                             24
# test_preparation_course           23
# math_score                         0
# reading_score                      0
# writing_score                     24
# science_score                     23
# total_score                       19
# grade                              3
# dtype: int64

# %%
# # Detect and Fix Inconsistencies
df[ (df['writing_score'] < 25) | (df['writing_score'] > 75) ]
# Out:
#       roll_no  gender race_ethnicity parental_level_of_education  lunch  \
# 0         NaN    male        group D                some college    1.0
# 2         NaN    male        group C             master's degree    1.0
# 6         NaN     NaN        group C                some college    0.0
# 8         NaN    male        group C                         NaN    1.0
# 9         NaN    male        group C            some high school    NaN
# ...       ...     ...            ...                         ...    ...
# 9994      NaN  female        group B           bachelor's degree    1.0
# 9996      NaN  female        group C           bachelor's degree    1.0
# 9997      NaN  female        group B          associate's degree    1.0
# 9998      NaN  female        group B            some high school    1.0
# 9999      NaN  female        group B                 high school    1.0
#
#       test_preparation_course  math_score  reading_score  writing_score  \
# ...

# %%
df['writing_score'] = df['writing_score'].clip(0,100)

# %%
df['writing_score'].describe()
# Out:
# count    9976.000000
# mean       71.415798
# std        18.245360
# min        10.000000
# 25%        59.000000
# 50%        72.500000
# 75%        85.000000
# max       100.000000
# Name: writing_score, dtype: float64

# %%
Q1 = df['total_score'].quantile(0.25)
Q3 = df['total_score'].quantile(0.75)
IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

outlier = df[(df['total_score'] < lower) | (df['total_score'] > upper)]
print(outlier)
# Out:
#       roll_no  gender race_ethnicity parental_level_of_education  lunch  \
# 129       NaN    male        group B             master's degree    1.0
# 178       NaN    male        group D          associate's degree    1.0
# 223       NaN    male        group D           bachelor's degree    1.0
# 282       NaN    male        group D           bachelor's degree    1.0
# 292       NaN    male        group D           bachelor's degree    1.0
# ...       ...     ...            ...                         ...    ...
# 6648      NaN  female        group E                 high school    1.0
# 7554      NaN  female        group D          associate's degree    0.0
# 8034      NaN  female            NaN             master's degree    1.0
# 8436      NaN  female        group C             master's degree    1.0
# 8778      NaN  female        group C            some high school    1.0
#
#       test_preparation_course  math_score  reading_score  writing_score  \
# ...

# %%
df['total_score'].describe()
# Out:
# count    9981.000000
# mean      264.740908
# std        42.304858
# min        89.000000
# 25%       237.000000
# 50%       268.000000
# 75%       294.000000
# max       383.000000
# Name: total_score, dtype: float64

# %%
#  show the chart

plt.hist(df['total_score'])
plt.title('Histplot of the total score')
plt.show()

# %%
df['total_score'].hist()
# Out:
# <Axes: >

# %%
max_att = df['total_score'].max()
df['total_score_reflect'] = max_att + 1 - df['total_score']

# %%
df['total_score_reflect'].hist()
# Out:
# <Axes: >

# %%
# # Identify Skewed Data
# ## Check skewness

df['total_score'].skew()
# Out:
# np.float64(-0.3077630026709842)

# %%
# # Apply Data Transformation (Mandatory Step)
# ## Log Transformation

# %%
df['sqrt_total_score'] = np.sqrt(df['total_score'])

# %%
df['sqrt_total_score']
# Out:
# 0       15.427249
# 1       18.110770
# 2       16.248077
# 3       14.071247
# 4       14.594520
#           ...
# 9995    15.556349
# 9996    17.349352
# 9997    18.193405
# 9998    18.330303
# 9999    17.117243
# Name: sqrt_total_score, Length: 10000, dtype: float64

# %%
df['sqrt_total_score'].skew()
# Out:
# np.float64(-0.5567205039685346)

# %%
df['Log_total_score'] = np.log(df['total_score'])
df
# Out:
#       roll_no  gender race_ethnicity parental_level_of_education  lunch  \
# 0         NaN    male        group D                some college    1.0
# 1         NaN    male        group B                 high school    1.0
# 2         NaN    male        group C             master's degree    1.0
# 3         NaN    male        group D                some college    1.0
# 4         NaN    male        group C                some college    0.0
# ...       ...     ...            ...                         ...    ...
# 9995      NaN  female        group C                some college    1.0
# 9996      NaN  female        group C           bachelor's degree    1.0
# 9997      NaN  female        group B          associate's degree    1.0
# 9998      NaN  female        group B            some high school    1.0
# 9999      NaN  female        group B                 high school    1.0
#
#       test_preparation_course  math_score  reading_score  writing_score  \
# ...

# %%
df['Log_total_score'].skew()
# Out:
# np.float64(-0.8400815702538406)

# %%
df['total_score_transformed'] = df['total_score'] **1.7

# %%
df['total_score_transformed'].skew()
# Out:
# np.float64(0.003779898905755942)

# %%
df['total_score_transformed'].hist()
# Out:
# <Axes: >

# %%
df['total_score'].hist()
# Out:
# <Axes: >
